# %%
# !pip3 install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\shubh\anaconda3\lib\site-packages (2.1.2)
# Requirement already satisfied: torchvision in c:\users\shubh\anaconda3\lib\site-packages (0.16.2)
# Requirement already satisfied: torchaudio in c:\users\shubh\anaconda3\lib\site-packages (2.1.2)
# Requirement already satisfied: networkx in c:\users\shubh\anaconda3\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: fsspec in c:\users\shubh\anaconda3\lib\site-packages (from torch) (2022.7.1)
# Requirement already satisfied: sympy in c:\users\shubh\anaconda3\lib\site-packages (from torch) (1.10.1)
# Requirement already satisfied: jinja2 in c:\users\shubh\anaconda3\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: filelock in c:\users\shubh\anaconda3\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: typing-extensions in c:\users\shubh\anaconda3\lib\site-packages (from torch) (4.3.0)
# Requirement already satisfied: numpy in c:\users\shubh\anaconda3\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: requests in c:\users\shubh\anaconda3\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\shubh\anaconda3\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\shubh\anaconda3\lib\site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shubh\anaconda3\lib\site-packages (from requests->torchvision) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shubh\anaconda3\lib\site-packages (from requests->torchvision) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\shubh\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shubh\anaconda3\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\shubh\anaconda3\lib\site-packages (from sympy->torch) (1.2.1)

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !pip install -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt
# Out:
# Collecting gitpython>=3.1.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.24.4 which is incompatible.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      -------------------------------------- 190.6/190.6 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 6)) (3.5.2)
# Collecting numpy>=1.22.2
#   Downloading numpy-1.26.3-cp39-cp39-win_amd64.whl (15.8 MB)
#      --------------------------------------- 15.8/15.8 MB 16.4 MB/s eta 0:00:00
# Collecting opencv-python>=4.1.1
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#      --------------------------------------- 38.6/38.6 MB 14.9 MB/s eta 0:00:00
# Collecting Pillow>=10.0.1
#   Downloading pillow-10.2.0-cp39-cp39-win_amd64.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 12)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 13)) (1.9.1)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 16)) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 17)) (4.64.1)
# Collecting ultralytics>=8.0.232
#   Downloading ultralytics-8.0.234-py3-none-any.whl (664 kB)
#      ------------------------------------- 664.3/664.3 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 27)) (1.4.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\shubh\anaconda3\lib\site-packages (from -r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 28)) (0.11.2)
# Collecting setuptools>=65.5.1
#   Downloading setuptools-69.0.3-py3-none-any.whl (819 kB)
#      ------------------------------------- 819.5/819.5 kB 12.8 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.7/62.7 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shubh\anaconda3\lib\site-packages (from matplotlib>=3.3->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 6)) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shubh\anaconda3\lib\site-packages (from matplotlib>=3.3->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\shubh\anaconda3\lib\site-packages (from matplotlib>=3.3->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 6)) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shubh\anaconda3\lib\site-packages (from matplotlib>=3.3->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shubh\anaconda3\lib\site-packages (from matplotlib>=3.3->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\shubh\anaconda3\lib\site-packages (from matplotlib>=3.3->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shubh\anaconda3\lib\site-packages (from requests>=2.23.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 12)) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\shubh\anaconda3\lib\site-packages (from requests>=2.23.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shubh\anaconda3\lib\site-packages (from requests>=2.23.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 12)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shubh\anaconda3\lib\site-packages (from requests>=2.23.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 12)) (1.26.11)
# Collecting numpy>=1.22.2
#   Downloading numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
#      --------------------------------------- 14.9/14.9 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in c:\users\shubh\anaconda3\lib\site-packages (from torch>=1.8.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (2022.7.1)
# Requirement already satisfied: typing-extensions in c:\users\shubh\anaconda3\lib\site-packages (from torch>=1.8.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (4.3.0)
# Requirement already satisfied: jinja2 in c:\users\shubh\anaconda3\lib\site-packages (from torch>=1.8.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (2.11.3)
# Requirement already satisfied: filelock in c:\users\shubh\anaconda3\lib\site-packages (from torch>=1.8.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: networkx in c:\users\shubh\anaconda3\lib\site-packages (from torch>=1.8.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (2.8.4)
# Requirement already satisfied: sympy in c:\users\shubh\anaconda3\lib\site-packages (from torch>=1.8.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (1.10.1)
# Requirement already satisfied: colorama in c:\users\shubh\anaconda3\lib\site-packages (from tqdm>=4.64.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 17)) (0.4.5)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shubh\anaconda3\lib\site-packages (from pandas>=1.1.4->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 27)) (2022.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in c:\users\shubh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\shubh\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\shubh\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->-r C:\Users\shubh\OneDrive\Desktop\Drowsiness\yolov5\requirements.txt (line 15)) (1.2.1)
# Installing collected packages: py-cpuinfo, smmap, setuptools, Pillow, numpy, opencv-python, gitdb, thop, gitpython, ultralytics
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 63.4.1
#     Uninstalling setuptools-63.4.1:
#       Successfully uninstalled setuptools-63.4.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.2.0
#     Uninstalling Pillow-9.2.0:
#       Successfully uninstalled Pillow-9.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Successfully installed Pillow-10.2.0 gitdb-4.0.11 gitpython-3.1.40 numpy-1.24.4 opencv-python-4.9.0.80 py-cpuinfo-9.0.0 setuptools-69.0.3 smmap-5.0.1 thop-0.1.1.post2209072238 ultralytics-8.0.234

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model=torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# C:\Users\shubh\anaconda3\lib\site-packages\torch\hub.py:294: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\shubh/.cache\torch\hub\master.zip
# YOLOv5  2024-1-4 Python-3.9.13 torch-2.1.2+cpu CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|█████████████████████████████████████████████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 28.1MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (3): Conv(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (4): C3(
#           (cv1): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (5): Conv(
#           (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (6): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (7): Conv(
#           (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (8): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (9): SPPF(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#         )
#         (10): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (11): Upsample(scale_factor=2.0, mode='nearest')
#         (12): Concat()
#         (13): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (14): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (15): Upsample(scale_factor=2.0, mode='nearest')
#         (16): Concat()
#         (17): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (18): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (19): Concat()
#         (20): C3(
#           (cv1): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (21): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (22): Concat()
#         (23): C3(
#           (cv1): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#               (cv2): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                 (act): SiLU(inplace=True)
#               )
#             )
#           )
#         )
#         (24): Detect(
#           (m): ModuleList(
#             (0): Conv2d(128, 255, kernel_size=(1, 1), stride=(1, 1))
#             (1): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#             (2): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#       )
#     )
#   )
# )

# %%
img='https://www.ultralytics.com/images/zidane.jpg'

# %%
results=model(img)
results.print();
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1598.6ms pre-process, 342.8ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[72, 48, 38],
#          [74, 50, 40],
#          [73, 51, 40],
#          ...,
#          [56, 21, 25],
#          [55, 19, 21],
#          [51, 15, 17]],
#
#         [[71, 47, 37],
#          [71, 47, 37],
#          [70, 48, 37],
#          ...,
#          [55, 20, 24],
#          [52, 16, 18],
#          [47, 11, 13]],
#
#         [[75, 51, 41],
#          [73, 49, 39],
#          [70, 48, 37],
#          ...,
#          [56, 20, 24],
#          [52, 16, 20],
#          [48, 12, 16]],
#
#         ...,
#
#         [[40, 43, 48],
#          [41, 44, 49],
#          [40, 43, 48],
#          ...,
#          [35, 49, 49],
#          [35, 49, 49],
#          [36, 50, 50]],
#
#         [[39, 42, 49],
#          [39, 42, 49],
#          [39, 42, 49],
#          ...,
#          [35, 49, 50],
#          [35, 49, 50],
#          [36, 50, 51]],
#
#         [[38, 41, 48],
#          [38, 41, 48],
#          [38, 41, 48],
#          ...,
#          [35, 49, 50],
#          [35, 49, 50],
#          [36, 50, 51]]], dtype=uint8)]

# %%
cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame=cap.read()
    results=model(frame)
    cv2.imshow('YOLO',np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF==ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
